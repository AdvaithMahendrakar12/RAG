# %%
import numpy as np 
import matplotlib.pyplot as plt

#use matplot to visulise vectors


def cosine_similarity(vec1 , vec2) :
    # a.b/moda.mod b
    dot_product = np.dot(vec1,vec2) 
    norm_a = np.linalg.norm(vec1)
    norm_b = np.linalg.norm(vec2)
    
    return dot_product/(norm_a * norm_b)

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(); 
#model name here 
#use SentenceTransformersEmbeddings - sentence-transformers/all-MiniLM-L6-v2

# %%
text = "Hello Advaith"
embeddings.embed_query(text)

# %%
#then play with OpenAI model 
from langchain_openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
embedded = embeddings.embed_query(text)


#Semnatic search
def semantic_search(query, documents, embeddings,top_k=5): 
    query_embedding = embeddings.embed_query(query)
    document_embeddings = [embeddings.embed_query(doc) for doc in documents]
